# %% [markdown]
# ##Evolução do Corona Vírus no Brasil

# %% [markdown]
# ANALISE COVID 19 BRASIL
# Copyright 2020 The GooGolPlex Authors. Licensed under the Apache License, Version 2.0 (the "License");
#
# Data Scientist Jose R F Junior - web2ajax@gmail.com Project: COVID 19

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# SPARK E JAVA

# %%
# !apt-get install openjdk-8-jdk-headless -qq > /dev/null
# !wget -q https://downloads.apache.org/spark/spark-3.0.0/spark-3.0.0-bin-hadoop3.2.tgz
# !tar xf spark-3.0.0-bin-hadoop3.2.tgz
# !pip install -q findspark
import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
os.environ["SPARK_HOME"] = "/content/spark-3.0.0-bin-hadoop3.2"
import findspark
findspark.init()
from pyspark import SparkContext, SparkConf
from pyspark.sql import SQLContext, SparkSession
from pyspark.sql.types import StructType, StructField, DoubleType, IntegerType, StringType
#Spark Contexto
sc = SparkSession.builder.master("local[*]").getOrCreate()
df = SparkContext.getOrCreate(SparkConf().setMaster("local[*]"))

# %%
from pyspark import SparkContext
from pyspark.sql import SQLContext
import pandas as pd
import bar_chart_race as bcr

# %%
# !pip install bar_chart_race

# %%
# !pip install ffmpeg

# %%
# %time ! git clone https://github.com/GCPBigData/MortesCovid

# %% [markdown]
# LER O CSV

# %%
df = pd.read_csv('/content/mortes.csv')

# %%
df.head()

# %%
df.slice_shift(100)

# %%
#df['date'] = pd.to_datetime(df['date'], errors='coerce')
#df['date'] = df['date'].dt.strftime('%m')

# %%
df = df.set_index('dia')

# %%
df.head(100)

# %%
df.columns

# %%
bcr.bar_chart_race(df = df, title = "COVID NO BRASIL - web2ajax@gmail.com")

# %%
bcr.bar_chart_race(df = df, title = "COVID NO BRASIL - web2ajax@gmail.com",n_bars=10, orientation='h', fixed_order= True, cmap = 'prism')

# %% [markdown]
# ##Crescimento População

# %%
df = pd.read_csv("https://raw.githubusercontent.com/dexplo/bar_chart_race/master/data/urban_pop.csv")

# %%
df.head()

# %%
df.slice_shift(40)

# %%
df = df.set_index('year')

# %%
df.head()

# %%
df.columns

# %%
bcr.bar_chart_race(df = df, title = "Crescimento População - web2ajax@gmail.com")

# %%
bcr.bar_chart_race(df = df, title = "Crescimento População - web2ajax@gmail.com",n_bars=10, orientation='h', fixed_order= True, cmap = 'prism')
